# %% [markdown]
# 1. Loading the Dataset

# %%
import pandas as pd
df = pd.read_csv('fifa_players.csv')
df
# Out:
#                  name                         full_name birth_date  age  \
# 0            L. Messi    Lionel Andrés Messi Cuccittini  6/24/1987   31
# 1          C. Eriksen      Christian  Dannemann Eriksen  2/14/1992   27
# 2            P. Pogba                        Paul Pogba  3/15/1993   25
# 3          L. Insigne                   Lorenzo Insigne   6/4/1991   27
# 4        K. Koulibaly                 Kalidou Koulibaly  6/20/1991   27
# ...               ...                               ...        ...  ...
# 17949     R. McKenzie                    Rory  McKenzie  10/7/1993   25
# 17950       M. Sipľak                     Michal Sipľak   2/2/1996   23
# 17951      J. Bekkema                       Jan Bekkema   4/9/1996   22
# 17952      A. Al Yami               Abdulrahman Al Yami  6/19/1997   21
# 17953  Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19
#
#        height_cm  weight_kgs  positions   nationality  overall_rating  \
# ...

# %%
df.head(10)
# Out:
#            name                          full_name  birth_date  age  \
# 0      L. Messi     Lionel Andrés Messi Cuccittini   6/24/1987   31
# 1    C. Eriksen       Christian  Dannemann Eriksen   2/14/1992   27
# 2      P. Pogba                         Paul Pogba   3/15/1993   25
# 3    L. Insigne                    Lorenzo Insigne    6/4/1991   27
# 4  K. Koulibaly                  Kalidou Koulibaly   6/20/1991   27
# 5   V. van Dijk                    Virgil van Dijk    7/8/1991   27
# 6     K. Mbappé                      Kylian Mbappé  12/20/1998   20
# 7     S. Agüero  Sergio Leonel Agüero del Castillo    6/2/1988   30
# 8      M. Neuer                       Manuel Neuer   3/27/1986   32
# 9     E. Cavani       Edinson Roberto Cavani Gómez   2/14/1987   32
#
#    height_cm  weight_kgs  positions  nationality  overall_rating  potential  \
# 0     170.18        72.1   CF,RW,ST    Argentina              94         94
# ...

# %%
df.shape
# Out:
# (17954, 51)

# %%
df.columns
# Out:
# Index(['name', 'full_name', 'birth_date', 'age', 'height_cm', 'weight_kgs',
#        'positions', 'nationality', 'overall_rating', 'potential', 'value_euro',
#        'wage_euro', 'preferred_foot', 'international_reputation(1-5)',
#        'weak_foot(1-5)', 'skill_moves(1-5)', 'body_type',
#        'release_clause_euro', 'national_team', 'national_rating',
#        'national_team_position', 'national_jersey_number', 'crossing',
#        'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'dribbling', 'curve', 'freekick_accuracy', 'long_passing',
#        'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions',
#        'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
#        'composure', 'marking', 'standing_tackle', 'sliding_tackle'],
#       dtype='object')

# %% [markdown]
# 2. Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           17954 non-null  object
#  1   full_name                      17954 non-null  object
#  2   birth_date                     17954 non-null  object
#  3   age                            17954 non-null  int64
#  4   height_cm                      17954 non-null  float64
#  5   weight_kgs                     17954 non-null  float64
#  6   positions                      17954 non-null  object
#  7   nationality                    17954 non-null  object
#  8   overall_rating                 17954 non-null  int64
#  9   potential                      17954 non-null  int64
#  10  value_euro                     17699 non-null  float64
#  11  wage_euro                      17708 non-null  float64
# ...

# %%
df.sample(5)
# Out:
#            name             full_name  birth_date  age  height_cm  weight_kgs  \
# 6143   M. Kokos          Marvin Kokos  10/12/2000   18     182.88        78.0
# 2867    J. Pohl           Jannik Pohl    4/6/1996   22     182.88        77.1
# 5009   A. Perea          Andrés Perea  11/14/2000   18     182.88        73.0
# 688       Dória  Matheus Dória Macedo   11/8/1994   24     187.96        82.1
# 8899  J. Bonham           Jack Bonham   9/14/1993   25     193.04        94.8
#
#      positions          nationality  overall_rating  potential  ...  \
# 6143        ST               France              57         70  ...
# 2867        ST              Denmark              65         76  ...
# 5009        CM             Colombia              50         73  ...
# 688         CB               Brazil              74         78  ...
# 8899        GK  Republic of Ireland              63         68  ...
#
#       long_shots  aggression interceptions  positioning  vision  penalties  \
# ...

# %%
df.isnull().sum()
# Out:
# name                                 0
# full_name                            0
# birth_date                           0
# age                                  0
# height_cm                            0
# weight_kgs                           0
# positions                            0
# nationality                          0
# overall_rating                       0
# potential                            0
# value_euro                         255
# wage_euro                          246
# preferred_foot                       0
# international_reputation(1-5)        0
# weak_foot(1-5)                       0
# skill_moves(1-5)                     0
# body_type                            0
# release_clause_euro               1837
# national_team                    17097
# national_rating                  17097
# national_team_position           17097
# national_jersey_number           17097
# crossing                             0
# finishing                            0
# ...

# %%
df.columns
# Out:
# Index(['name', 'full_name', 'birth_date', 'age', 'height_cm', 'weight_kgs',
#        'positions', 'nationality', 'overall_rating', 'potential', 'value_euro',
#        'wage_euro', 'preferred_foot', 'international_reputation(1-5)',
#        'weak_foot(1-5)', 'skill_moves(1-5)', 'body_type',
#        'release_clause_euro', 'national_team', 'national_rating',
#        'national_team_position', 'national_jersey_number', 'crossing',
#        'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'dribbling', 'curve', 'freekick_accuracy', 'long_passing',
#        'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions',
#        'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
#        'composure', 'marking', 'standing_tackle', 'sliding_tackle'],
#       dtype='object')

# %%
df['nationality'].unique()
# Out:
# array(['Argentina', 'Denmark', 'France', 'Italy', 'Senegal',
#        'Netherlands', 'Germany', 'Uruguay', 'Spain', 'Belgium', 'Egypt',
#        'Slovakia', 'Brazil', 'Croatia', 'Costa Rica', 'Colombia',
#        'Morocco', 'Portugal', 'Sweden', 'Bosnia Herzegovina', 'Mexico',
#        'England', 'Austria', 'Iceland', 'Hungary', 'Wales', 'Ukraine',
#        'Central African Rep.', 'Serbia', 'Ivory Coast', 'Cameroon',
#        'Paraguay', 'Australia', 'Algeria', 'Romania', 'Russia', 'Israel',
#        'Switzerland', 'Chile', 'Tunisia', 'Turkey', 'Nigeria', 'Peru',
#        'Norway', 'Greece', 'United States', 'Venezuela', 'Iran',
#        'Equatorial Guinea', 'Cape Verde', 'Tanzania', 'Scotland',
#        'China PR', 'Kosovo', 'Montenegro', 'Canada', 'Madagascar', 'Mali',
#        'Ghana', 'Guinea', 'Poland', 'Cuba', 'Northern Ireland', 'Japan',
#        'New Zealand', 'South Africa', 'Republic of Ireland', 'Ecuador',
# ...

# %%
df['nationality'].value_counts()
# Out:
# nationality
# England                 1658
# Germany                 1199
# Spain                   1070
# France                   925
# Argentina                904
#                         ...
# Papua New Guinea           1
# South Sudan                1
# Malta                      1
# Yemen                      1
# United Arab Emirates       1
# Name: count, Length: 160, dtype: int64

# %%
df['name']
# Out:
# 0              L. Messi
# 1            C. Eriksen
# 2              P. Pogba
# 3            L. Insigne
# 4          K. Koulibaly
#               ...
# 17949       R. McKenzie
# 17950         M. Sipľak
# 17951        J. Bekkema
# 17952        A. Al Yami
# 17953    Júnior Brumado
# Name: name, Length: 17954, dtype: object

# %%
df[['name','positions']]
# Out:
#                  name  positions
# 0            L. Messi   CF,RW,ST
# 1          C. Eriksen  CAM,RM,CM
# 2            P. Pogba     CM,CAM
# 3          L. Insigne      LW,ST
# 4        K. Koulibaly         CB
# ...               ...        ...
# 17949     R. McKenzie  RM,CAM,CM
# 17950       M. Sipľak         LB
# 17951      J. Bekkema         GK
# 17952      A. Al Yami      ST,LM
# 17953  Júnior Brumado         ST
#
# [17954 rows x 2 columns]

# %%
df[df['age'] > 32]
# Out:
#                     name                            full_name birth_date  age  \
# 17           Fernandinho                   Fernando Luiz Rosa   5/4/1985   33
# 45               Iniesta                 Andrés Iniesta Luján  5/11/1984   34
# 46        Z. Ibrahimović                   Zlatan Ibrahimović  10/3/1981   37
# 75        Juiano Mestres     Juan Everton Mestres de Mesquita  2/29/1984   35
# 79             M. Parolo                         Marco Parolo  1/25/1985   34
# ...                  ...                                  ...        ...  ...
# 17930       G. Chiellini                    Giorgio Chiellini  8/14/1984   34
# 17932        David Silva            David Josué Jiménez Silva   1/8/1986   33
# 17933           D. Godín                          Diego Godín  2/16/1986   33
# 17939          L. Modrić                          Luka Modrić   9/9/1985   33
# 17944  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   2/5/1985   34
#
# ...

# %%
df[df['nationality'] == 'Spain']
# Out:
#                   name                       full_name birth_date  age  \
# 10     Sergio Busquets        Sergio Busquets i Burgos  7/16/1988   30
# 24          Jordi Alba                Jordi Alba Ramos  3/21/1989   29
# 25              Thiago  Thiago Alcântara do Nascimento  4/11/1991   27
# 28                Isco  Francisco Román Alarcón Suárez  4/21/1992   26
# 32                Kepa               Kepa Arrizabalaga  10/3/1994   24
# ...                ...                             ...        ...  ...
# 17903      Azpilicueta         César Azpilicueta Tanco  8/28/1989   29
# 17920            Piqué           Gerard Piqué Bernabéu   2/2/1987   32
# 17931     Sergio Ramos             Sergio Ramos García  3/30/1986   32
# 17932      David Silva       David Josué Jiménez Silva   1/8/1986   33
# 17942           De Gea           David De Gea Quintana  11/7/1990   28
#
#        height_cm  weight_kgs   positions nationality  overall_rating  \
# ...

# %%
df[(df['nationality'] == 'Argentina') & (df['overall_rating'] > 85)]
# Out:
#           name                          full_name  birth_date  age  height_cm  \
# 0     L. Messi     Lionel Andrés Messi Cuccittini   6/24/1987   31     170.18
# 7    S. Agüero  Sergio Leonel Agüero del Castillo    6/2/1988   30     172.72
# 15   P. Dybala        Paulo Bruno Exequiel Dybala  11/15/1993   25     152.40
# 18  G. Higuaín            Gonzalo Gerardo Higuaín  12/10/1987   31     185.42
# 31   M. Icardi        Mauro Emanuel Icardi Rivero   2/19/1993   26     154.94
#
#     weight_kgs positions nationality  overall_rating  potential  ...  \
# 0         72.1  CF,RW,ST   Argentina              94         94  ...
# 7         69.9        ST   Argentina              89         89  ...
# 15        74.8    CAM,RW   Argentina              89         94  ...
# 18        88.9        ST   Argentina              87         87  ...
# 31        74.8        ST   Argentina              87         90  ...
#
#     long_shots  aggression interceptions  positioning  vision  penalties  \
# ...

# %%
df.sort_values(by='overall_rating', ascending=False)
# Out:
#                     name                            full_name  birth_date  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   6/24/1987
# 17944  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro    2/5/1985
# 17943          Neymar Jr        Neymar da Silva Santos Junior    2/5/1992
# 17939          L. Modrić                          Luka Modrić    9/9/1985
# 17942             De Gea                David De Gea Quintana   11/7/1990
# ...                  ...                                  ...         ...
# 4877           O. Antman                        Oliver Antman    8/1/2001
# 4878          I. Häggman                         Isac Häggman    1/9/2002
# 4880            J. Milli                         Joakim Milli   4/27/2000
# 4881          K. Catalán                        Kevin Catalán    4/2/1999
# 4879          S. Griffin                        Shane Griffin  12/31/1999
#
#        age  height_cm  weight_kgs positions          nationality  \
# ...

# %%
df.rename(columns={'overall_rating': 'Rating'}, inplace=True)

# %%
df.sort_values(by='Rating', ascending=False)
# Out:
#                     name                            full_name  birth_date  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   6/24/1987
# 17944  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro    2/5/1985
# 17943          Neymar Jr        Neymar da Silva Santos Junior    2/5/1992
# 17939          L. Modrić                          Luka Modrić    9/9/1985
# 17942             De Gea                David De Gea Quintana   11/7/1990
# ...                  ...                                  ...         ...
# 4877           O. Antman                        Oliver Antman    8/1/2001
# 4878          I. Häggman                         Isac Häggman    1/9/2002
# 4880            J. Milli                         Joakim Milli   4/27/2000
# 4881          K. Catalán                        Kevin Catalán    4/2/1999
# 4879          S. Griffin                        Shane Griffin  12/31/1999
#
#        age  height_cm  weight_kgs positions          nationality  Rating  \
# ...

# %%
df['Age_Rating'] = df['age'] * df['Rating']

# %%
df.groupby('nationality')['Rating'].mean()
# Out:
# nationality
# Afghanistan    61.333333
# Albania        66.380952
# Algeria        70.866667
# Andorra        62.000000
# Angola         68.846154
#                  ...
# Vietnam        62.000000
# Wales          64.246154
# Yemen          58.000000
# Zambia         65.400000
# Zimbabwe       69.153846
# Name: Rating, Length: 160, dtype: float64

# %%
df.groupby(['nationality', 'age']).size()
# Out:
# nationality  age
# Afghanistan  21     1
#              22     1
#              27     1
# Albania      19     3
#              20     2
#                    ..
# Zimbabwe     25     2
#              27     2
#              28     2
#              31     1
#              33     2
# Length: 1731, dtype: int64

# %%
df['Rating'].agg(['mean', 'min', 'max'])
# Out:
# mean    66.240169
# min     47.000000
# max     94.000000
# Name: Rating, dtype: float64

# %%
df[['age', 'Rating']].agg(['mean', 'std'])
# Out:
#             age     Rating
# mean  25.565445  66.240169
# std    4.705708   6.963730

# %% [markdown]
# Let's visualize our data using matplotlib///

# %%
import matplotlib.pyplot as plt

# %%
df['age'].hist()
df['age'].hist()
plt.title('Distribution of Players Ages')
plt.xlabel('age')
plt.ylabel('Frequency')
plt.show()
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\samir\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\samir\AppData\Local\Temp\ipykernel_13788\2703049496.py", line 1, in <module>
#     df['age'].hist()
#   File "C:\Users\samir\anaconda3\Lib\site-packages\pandas\plotting\_core.py", line 124, in hist_series
#     >>> lst = ['a', 'a', 'a', 'b', 'b', 'b']
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\samir\anaconda3\Lib\site-packages\pandas\plotting\_core.py", line 1947, in _get_plot_backend
#   File "C:\Users\samir\anaconda3\Lib\site-packages\pandas\plotting\_core.py", line 1877, in _load_backend
#     ) from None
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
#
# ...
